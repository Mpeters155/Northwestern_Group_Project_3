# %%
from nixtlats import TimeGPT
import pandas as pd

# %%
timegpt = TimeGPT(
    # defaults to os.environ.get("TIMEGPT_TOKEN")
    token = '')

# %%
timegpt.validate_token()
# Out:
# INFO:nixtlats.timegpt:Happy Forecasting! :), If you have questions or need support, please email ops@nixtla.io
# True

# %%
df = pd.read_csv('VTSAX.csv')
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0  2019-03-29  70.430000  70.430000  70.430000  70.430000  65.290108     0.0
# 1  2019-04-01  71.239998  71.239998  71.239998  71.239998  66.041023     0.0
# 2  2019-04-02  71.230003  71.230003  71.230003  71.230003  66.031754     0.0
# 3  2019-04-03  71.419998  71.419998  71.419998  71.419998  66.207848     0.0
# 4  2019-04-04  71.559998  71.559998  71.559998  71.559998  66.337654     0.0

# %%
df.isna()
# Out:
#        Date   Open   High    Low  Close  Adj Close  Volume
# 0     False  False  False  False  False      False   False
# 1     False  False  False  False  False      False   False
# 2     False  False  False  False  False      False   False
# 3     False  False  False  False  False      False   False
# 4     False  False  False  False  False      False   False
# ...     ...    ...    ...    ...    ...        ...     ...
# 1254  False  False  False  False  False      False   False
# 1255  False  False  False  False  False      False   False
# 1256  False  False  False  False  False      False   False
# 1257  False  False  False  False  False      False   False
# 1258  False   True   True   True   True       True    True
#
# [1259 rows x 7 columns]

# %%
df.dropna(inplace = True)

# %%
df.isna()
# Out:
#        Date   Open   High    Low  Close  Adj Close  Volume
# 0     False  False  False  False  False      False   False
# 1     False  False  False  False  False      False   False
# 2     False  False  False  False  False      False   False
# 3     False  False  False  False  False      False   False
# 4     False  False  False  False  False      False   False
# ...     ...    ...    ...    ...    ...        ...     ...
# 1253  False  False  False  False  False      False   False
# 1254  False  False  False  False  False      False   False
# 1255  False  False  False  False  False      False   False
# 1256  False  False  False  False  False      False   False
# 1257  False  False  False  False  False      False   False
#
# [1258 rows x 7 columns]

# %%
timegpt.plot(df, time_col='Date', target_col='Open')

# %%
timegpt_fcst_finetune_df = timegpt.forecast(
    df=df, freq='MS', h=24, fewshot_steps=10,
    time_col='Date', target_col='Close',
)
# Out:
# INFO:nixtlats.timegpt:Validating inputs...
# INFO:nixtlats.timegpt:Preprocessing dataframes...
# WARNING:nixtlats.timegpt:The specified horizon "h" exceeds the model horizon. This may lead to less accurate forecasts. Please consider using a smaller horizon.
# INFO:nixtlats.timegpt:Calling Forecast Endpoint...

# %%
timegpt_fcst_finetune_df.head()
# Out:
#          Date     TimeGPT
# 0  2024-04-01  126.483253
# 1  2024-05-01  124.799644
# 2  2024-06-01  124.361763
# 3  2024-07-01  123.855583
# 4  2024-08-01  126.258781

# %%
timegpt.plot(
    df, timegpt_fcst_finetune_df, 
    time_col='Date', target_col='Close',
)
